# %%
import numpy as np
import h5py
import matplotlib.pyplot as plt

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
# load full data
# save examples for testing

with h5py.File('../data/training_30_64.hdf5', 'r') as f:
    maps = f['arr'][:]

# %%
maps.shape
# Out:
# (48088, 64, 64)

# %%
to_save = maps[1:4]

# %%
to_save.shape
# Out:
# (3, 64, 64)

# %%
for i in range(to_save.shape[0]):
    plt.imshow(to_save[i])
    print(to_save[i])
    plt.show()
# Out:
# [[ 0.   3.8  6.7 ... 41.3 39.4 37.8]
#  [ 3.8  0.   3.8 ... 40.2 38.1 36.3]
#  [ 6.7  3.8  0.  ... 38.3 35.9 34.3]
#  ...
#  [41.3 40.2 38.3 ...  0.   3.8  5.5]
#  [39.4 38.1 35.9 ...  3.8  0.   3.8]
#  [37.8 36.3 34.3 ...  5.5  3.8  0. ]]
# [[ 0.   3.8  5.7 ... 25.2 28.4 27. ]
#  [ 3.8  0.   3.8 ... 21.5 24.7 23.2]
#  [ 5.7  3.8  0.  ... 22.2 25.1 23.4]
#  ...
#  [25.2 21.5 22.2 ...  0.   3.8  5.5]
#  [28.4 24.7 25.1 ...  3.8  0.   3.8]
#  [27.  23.2 23.4 ...  5.5  3.8  0. ]]
# [[ 0.   3.8  5.6 ... 23.7 26.8 29. ]
#  [ 3.8  0.   3.8 ... 23.5 26.5 28.9]
#  [ 5.6  3.8  0.  ... 19.8 22.8 25.4]
#  ...
#  [23.7 23.5 19.8 ...  0.   3.7  6.8]
#  [26.8 26.5 22.8 ...  3.7  0.   3.8]
#  [29.  28.9 25.4 ...  6.8  3.8  0. ]]

# %%
with h5py.File('demo_disto.hdf5', 'w') as f:
    dset = f.create_dataset('arr', data=to_save, compression='gzip')
